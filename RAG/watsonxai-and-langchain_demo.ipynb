# %% [markdown]
# # Lab: Using LangChain with IBM WatsonX
#
# ## 1. Intro to LangChain
#
# [LangChain](https://docs.langchain.com/docs/) is an open-source development framework designed to simplify the creation of applications using large language models (LLMs).
#
# The core idea of the library is that we can "chain" together different components to create more advanced use cases around LLMs. Here are the main components for the LangChain
#
# - Model: interact with various LLMs
# - Prompts: text that is sent to the LLMs
# - Chains: allow to combine different LLM calls and actions automatically
# - Embeddings and Vector Stores: break large data into chunks and store those to be queried when relevant
# - Agents: enbale the LLMs to dynamically decide which tools to use in order to best respond to a given query
#
# In short, **Langchain is a framework that can orchestrate a series of prompts to achieve a desired outcomes.**

# %% [markdown]
# ## 2. How to connect LangChain to WatsonX.ai

# %%
# !pip install chromadb==0.4.2 \
ibm-watson-machine-learning==1.0.311 \
ipywidgets==8.0.7 \
jupyter==1.0.0 \
langchain==0.0.236 \
matplotlib==3.7.2 \
numpy==1.24.2 \
pandas==1.5.3 \
plotly==5.15.0 \
pypdf==3.12.2 \
python-dotenv==1.0.0 \
requests==2.31.0 \
urllib3==1.26.11 \
rouge==1.0.1 \
scikit-learn==1.2.2 \
sentence-transformers==2.2.2 \
streamlit==1.24.1 \
safetensors==0.3.1  \
PyPDF2
# Out:
# Collecting chromadb==0.4.2
#   Downloading chromadb-0.4.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting ibm-watson-machine-learning==1.0.311
#   Downloading ibm_watson_machine_learning-1.0.311-py3-none-any.whl.metadata (8.9 kB)
# Collecting ipywidgets==8.0.7
#   Downloading ipywidgets-8.0.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jupyter==1.0.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (1)
# Collecting langchain==0.0.236
#   Downloading langchain-0.0.236-py3-none-any.whl.metadata (14 kB)
# Collecting matplotlib==3.7.2
#   Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting numpy==1.24.2
#   Downloading numpy-1.24.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 93.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas==1.5.3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (1.5.3)
# Collecting plotly==5.15.0
#   Downloading plotly-5.15.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting pypdf==3.12.2
#   Downloading pypdf-3.12.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting python-dotenv==1.0.0
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests==2.31.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (2.31.0)
# Collecting urllib3==1.26.11
#   Downloading urllib3-1.26.11-py2.py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 35.4 MB/s eta 0:00:00
# Collecting rouge==1.0.1
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting scikit-learn==1.2.2
#   Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 115.0 MB/s eta 0:00:0000:0100:01
# Collecting sentence-transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 23.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting streamlit==1.24.1
#   Downloading streamlit-1.24.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting safetensors==0.3.1
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 95.3 MB/s eta 0:00:00
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 47.8 MB/s eta 0:00:00
# Collecting pydantic<2.0,>=1.9 (from chromadb==0.4.2)
#   Downloading pydantic-1.10.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 38.4 MB/s eta 0:00:00
# Collecting chroma-hnswlib==0.7.1 (from chromadb==0.4.2)
#   Downloading chroma-hnswlib-0.7.1.tar.gz (30 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fastapi<0.100.0,>=0.95.2 (from chromadb==0.4.2)
#   Downloading fastapi-0.99.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb==0.4.2)
#   Downloading uvicorn-0.24.0.post1-py3-none-any.whl.metadata (6.4 kB)
# Collecting posthog>=2.4.0 (from chromadb==0.4.2)
#   Downloading posthog-3.0.2-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.5.0 (from chromadb==0.4.2)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting pulsar-client>=3.1.0 (from chromadb==0.4.2)
#   Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb==0.4.2)
#   Downloading onnxruntime-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting tokenizers>=0.13.2 (from chromadb==0.4.2)
#   Downloading tokenizers-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting pypika>=0.48.9 (from chromadb==0.4.2)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 18.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb==0.4.2) (4.65.0)
# Collecting overrides>=7.3.1 (from chromadb==0.4.2)
#   Downloading overrides-7.4.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting importlib-resources (from chromadb==0.4.2)
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning==1.0.311) (2023.7.22)
# Requirement already satisfied: lomond in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning==1.0.311) (0.3.3)
# Requirement already satisfied: tabulate in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning==1.0.311) (0.8.10)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning==1.0.311) (23.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning==1.0.311) (6.0.0)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning==1.0.311) (2.12.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipywidgets==8.0.7) (6.19.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipywidgets==8.0.7) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipywidgets==8.0.7) (5.7.1)
# Collecting widgetsnbextension~=4.0.7 (from ipywidgets==8.0.7)
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.7 (from ipywidgets==8.0.7)
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: PyYAML>=5.4.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from langchain==0.0.236) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from langchain==0.0.236) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from langchain==0.0.236) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from langchain==0.0.236) (4.0.2)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain==0.0.236)
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl.metadata (22 kB)
# Collecting langsmith<0.0.11,>=0.0.10 (from langchain==0.0.236)
#   Downloading langsmith-0.0.10-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from langchain==0.0.236) (2.8.4)
# Collecting openapi-schema-pydantic<2.0,>=1.2 (from langchain==0.0.236)
#   Downloading openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 25.7 MB/s eta 0:00:00
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain==0.0.236)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.7.2) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.7.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.7.2) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.7.2) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.7.2) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.7.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.7.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pandas==1.5.3) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from requests==2.31.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from requests==2.31.0) (3.4)
# Requirement already satisfied: six in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from rouge==1.0.1) (1.16.0)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from scikit-learn==1.2.2) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from scikit-learn==1.2.2) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from scikit-learn==1.2.2) (2.2.0)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers==2.2.2)
#   Downloading transformers-4.35.2-py3-none-any.whl.metadata (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 34.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (2.0.1)
# Requirement already satisfied: torchvision in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (0.15.2)
# Collecting nltk (from sentence-transformers==2.2.2)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 96.2 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (0.1.97)
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers==2.2.2)
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl.metadata (14 kB)
# Collecting altair<6,>=4.0 (from streamlit==1.24.1)
#   Downloading altair-5.1.2-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from streamlit==1.24.1) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from streamlit==1.24.1) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from streamlit==1.24.1) (8.0.4)
# Collecting pillow>=6.2.0 (from matplotlib==3.7.2)
#   Downloading Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 105.0 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<5,>=3.20 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from streamlit==1.24.1) (4.21.12)
# Requirement already satisfied: pyarrow>=4.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from streamlit==1.24.1) (11.0.0)
# Collecting pympler<2,>=0.9 (from streamlit==1.24.1)
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 39.6 MB/s eta 0:00:00
# Collecting rich<14,>=10.11.0 (from streamlit==1.24.1)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting toml<2 (from streamlit==1.24.1)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting tzlocal<5,>=1.1 (from streamlit==1.24.1)
#   Downloading tzlocal-4.3.1-py3-none-any.whl.metadata (14 kB)
# Collecting validators<1,>=0.2 (from streamlit==1.24.1)
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting gitpython!=3.1.19,<4,>=3 (from streamlit==1.24.1)
#   Downloading GitPython-3.1.40-py3-none-any.whl.metadata (12 kB)
# Collecting pydeck<1,>=0.1.dev5 (from streamlit==1.24.1)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 110.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from streamlit==1.24.1) (6.3.3)
# Collecting watchdog (from streamlit==1.24.1)
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.236) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.236) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.236) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.236) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.236) (1.2.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.24.1) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.24.1) (4.17.3)
# Requirement already satisfied: toolz in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.24.1) (0.12.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.236)
#   Downloading marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.236)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.100.0,>=0.95.2->chromadb==0.4.2)
#   Downloading starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3->streamlit==1.24.1)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.9.0)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2)
#   Downloading fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: ibm-cos-sdk-core==2.12.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning==1.0.311) (2.12.0)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.12.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning==1.0.311) (2.12.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.10.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning==1.0.311) (0.10.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from importlib-metadata->ibm-watson-machine-learning==1.0.311) (3.11.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.7) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.7) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.7) (8.1.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.7) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.7) (1.5.5)
# Requirement already satisfied: psutil in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.7) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.7) (23.2.0)
# Requirement already satisfied: backcall in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.0.7) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.0.7) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.0.7) (0.18.1)
# Requirement already satisfied: pickleshare in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.0.7) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.0.7) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.0.7) (2.15.1)
# Requirement already satisfied: stack-data in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.0.7) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.0.7) (4.8.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.4.2)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.2) (2.0)
# Requirement already satisfied: sympy in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.2) (1.11.1)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.4.2)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.4.2)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.11.0->streamlit==1.24.1)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.236) (2.0.1)
# Requirement already satisfied: networkx in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (2.8.4)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2)
#   Downloading regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 8.7 MB/s eta 0:00:00
# Collecting pytz-deprecation-shim (from tzlocal<5,>=1.1->streamlit==1.24.1)
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting h11>=0.8 (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.4.2)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 16.0 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.2)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.2)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.4.2)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.4.2)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit==1.24.1)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.0.7) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit==1.24.1) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.24.1) (0.18.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.7) (5.3.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit==1.24.1)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.0.7) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets==8.0.7) (0.2.5)
# Collecting anyio<5,>=3.4.0 (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.2)
#   Downloading anyio-4.0.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.236) (0.4.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.2)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 24.6 MB/s eta 0:00:00
# Collecting tzdata (from pytz-deprecation-shim->tzlocal<5,>=1.1->streamlit==1.24.1)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 62.4 MB/s eta 0:00:00
# Requirement already satisfied: executing in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.7) (0.8.3)
# Requirement already satisfied: asttokens in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.7) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.7) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.2) (1.3.0)
# Collecting sniffio>=1.1 (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.2)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.2)
#   Downloading exceptiongroup-1.1.3-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.7) (2.5.2)
# Downloading chromadb-0.4.2-py3-none-any.whl (399 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 59.3 MB/s eta 0:00:00
# Downloading ibm_watson_machine_learning-1.0.311-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 100.7 MB/s eta 0:00:00
# Downloading ipywidgets-8.0.7-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 38.4 MB/s eta 0:00:00
# Downloading langchain-0.0.236-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 98.8 MB/s eta 0:00:00
# Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 98.7 MB/s eta 0:00:00:00:010:01
# Downloading plotly-5.15.0-py2.py3-none-any.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 101.3 MB/s eta 0:00:0000:0100:01
# Downloading pypdf-3.12.2-py3-none-any.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.0/255.0 kB 53.1 MB/s eta 0:00:00
# Downloading streamlit-1.24.1-py2.py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 118.5 MB/s eta 0:00:0000:0100:01
# Downloading altair-5.1.2-py3-none-any.whl (516 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.2/516.2 kB 71.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 14.8 MB/s eta 0:00:00
# Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 43.2 MB/s eta 0:00:00
# Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 59.5 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 46.7 MB/s eta 0:00:00
# Downloading langsmith-0.0.10-py3-none-any.whl (27 kB)
# Downloading onnxruntime-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 115.5 MB/s eta 0:00:00a 0:00:01
# Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 105.6 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic-1.10.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 114.1 MB/s eta 0:00:00
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 55.1 MB/s eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading tokenizers-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.3 MB/s eta 0:00:0000:01
# Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 115.3 MB/s eta 0:00:00a 0:00:01
# Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Downloading uvicorn-0.24.0.post1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 16.4 MB/s eta 0:00:00
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 91.3 MB/s eta 0:00:00
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 37.3 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 19.1 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 68.4 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 26.0 MB/s eta 0:00:00
# Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 14.9 MB/s eta 0:00:00
# Downloading regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.9/773.9 kB 87.9 MB/s eta 0:00:00
# Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 20.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 109.9 MB/s eta 0:00:00
# Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 103.8 MB/s eta 0:00:00
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 36.7 MB/s eta 0:00:00
# Downloading anyio-4.0.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 25.9 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Downloading exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Building wheels for collected packages: sentence-transformers, chroma-hnswlib, pypika
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=a7a16880f69b4232ab9087e88eac5ef405f9836413f4a484603cfd3c8e0ee6cf
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for chroma-hnswlib (pyproject.toml) ... done
#   Created wheel for chroma-hnswlib: filename=chroma_hnswlib-0.7.1-cp310-cp310-linux_x86_64.whl size=181705 sha256=5c0eb6bcdc3eb736db5da624571ef2ce843ab0f41e64a6f6ee4d6a4f3baa783f
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/ad/f2/d2/3f32228e9f4713a9f32a468de8bbc3c642f7805ebef888418b
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=20730569c919f7b055d01cebac6dea1e8b7704b8cfa8641c093ffcd601da72d7
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built sentence-transformers chroma-hnswlib pypika
# Installing collected packages: safetensors, pypika, monotonic, widgetsnbextension, websockets, watchdog, validators, uvloop, urllib3, tzdata, typing-extensions, toml, tenacity, sniffio, smmap, rouge, regex, python-dotenv, PyPDF2, pypdf, pympler, pulsar-client, pillow, overrides, numpy, mdurl, marshmallow, jupyterlab-widgets, importlib-resources, humanfriendly, httptools, h11, fsspec, exceptiongroup, backoff, uvicorn, typing-inspect, pytz-deprecation-shim, pydeck, pydantic, plotly, nltk, markdown-it-py, gitdb, coloredlogs, chroma-hnswlib, anyio, watchfiles, tzlocal, starlette, scikit-learn, rich, posthog, openapi-schema-pydantic, onnxruntime, matplotlib, langsmith, huggingface-hub, gitpython, dataclasses-json, altair, tokenizers, streamlit, langchain, fastapi, transformers, ipywidgets, chromadb, sentence-transformers, ibm-watson-machine-learning
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.5
#     Uninstalling widgetsnbextension-4.0.5:
#       Successfully uninstalled widgetsnbextension-4.0.5
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.18
#     Uninstalling urllib3-1.26.18:
#       Successfully uninstalled urllib3-1.26.18
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 10.0.1
#     Uninstalling Pillow-10.0.1:
#       Successfully uninstalled Pillow-10.0.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.5
#     Uninstalling jupyterlab-widgets-3.0.5:
#       Successfully uninstalled jupyterlab-widgets-3.0.5
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.9.0
#     Uninstalling plotly-5.9.0:
#       Successfully uninstalled plotly-5.9.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.1
#     Uninstalling scikit-learn-1.1.1:
#       Successfully uninstalled scikit-learn-1.1.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.0.4
#     Uninstalling ipywidgets-8.0.4:
#       Successfully uninstalled ipywidgets-8.0.4
#   Attempting uninstall: ibm-watson-machine-learning
#     Found existing installation: ibm-watson-machine-learning 1.0.330
#     Uninstalling ibm-watson-machine-learning-1.0.330:
#       Successfully uninstalled ibm-watson-machine-learning-1.0.330
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autoai-libs 1.15.2 requires numpy<1.24,>=1.20.3; python_version >= "3.9", but you have numpy 1.24.2 which is incompatible.
# autoai-libs 1.15.2 requires scikit-learn<1.2,>=1.0.2; python_version >= "3.9", but you have scikit-learn 1.2.2 which is incompatible.
# autoai-ts-libs 3.0.13 requires numpy<1.24,>=1.19.2; python_version >= "3.9", but you have numpy 1.24.2 which is incompatible.
# autoai-ts-libs 3.0.13 requires scikit-learn<=1.1.1,>=1.0.2; python_version >= "3.9", but you have scikit-learn 1.2.2 which is incompatible.
# lale 0.7.7 requires numpy<1.24, but you have numpy 1.24.2 which is incompatible.
# lale 0.7.7 requires scikit-learn<=1.2.0,>=1.0.0, but you have scikit-learn 1.2.2 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.2 which is incompatible.
# Successfully installed PyPDF2-3.0.1 altair-5.1.2 anyio-4.0.0 backoff-2.2.1 chroma-hnswlib-0.7.1 chromadb-0.4.2 coloredlogs-15.0.1 dataclasses-json-0.5.14 exceptiongroup-1.1.3 fastapi-0.99.1 fsspec-2023.10.0 gitdb-4.0.11 gitpython-3.1.40 h11-0.14.0 httptools-0.6.1 huggingface-hub-0.19.4 humanfriendly-10.0 ibm-watson-machine-learning-1.0.311 importlib-resources-6.1.1 ipywidgets-8.0.7 jupyterlab-widgets-3.0.9 langchain-0.0.236 langsmith-0.0.10 markdown-it-py-3.0.0 marshmallow-3.20.1 matplotlib-3.7.2 mdurl-0.1.2 monotonic-1.6 nltk-3.8.1 numpy-1.24.2 onnxruntime-1.16.2 openapi-schema-pydantic-1.2.4 overrides-7.4.0 pillow-9.5.0 plotly-5.15.0 posthog-3.0.2 pulsar-client-3.3.0 pydantic-1.10.13 pydeck-0.8.1b0 pympler-1.0.1 pypdf-3.12.2 pypika-0.48.9 python-dotenv-1.0.0 pytz-deprecation-shim-0.1.0.post0 regex-2023.10.3 rich-13.7.0 rouge-1.0.1 safetensors-0.3.1 scikit-learn-1.2.2 sentence-transformers-2.2.2 smmap-5.0.1 sniffio-1.3.0 starlette-0.27.0 streamlit-1.24.1 tenacity-8.2.3 tokenizers-0.15.0 toml-0.10.2 transformers-4.35.2 typing-extensions-4.8.0 typing-inspect-0.9.0 tzdata-2023.3 tzlocal-4.3.1 urllib3-1.26.11 uvicorn-0.24.0.post1 uvloop-0.19.0 validators-0.22.0 watchdog-3.0.0 watchfiles-0.21.0 websockets-12.0 widgetsnbextension-4.0.9

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: pandas>=1.3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (1.5.3)
# Requirement already satisfied: requests>=2.28 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (1.10.13)
# Requirement already satisfied: chroma-hnswlib==0.7.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (0.7.1)
# Requirement already satisfied: fastapi<0.100.0,>=0.95.2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (0.99.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0.post1)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (1.24.2)
# Requirement already satisfied: posthog>=2.4.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (4.8.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (1.16.2)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (0.15.0)
# Requirement already satisfied: pypika>=0.48.9 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from fastapi<0.100.0,>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: coloredlogs in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (2.0)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.0)
# Requirement already satisfied: protobuf in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (4.21.12)
# Requirement already satisfied: sympy in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pandas>=1.3->chromadb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pandas>=1.3->chromadb) (2022.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pulsar-client>=3.1.0->chromadb) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from requests>=2.28->chromadb) (1.26.11)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb) (0.19.4)
# Requirement already satisfied: click>=7.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (8.0.4)
# Requirement already satisfied: h11>=0.8 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.10.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (4.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.1.3)

# %%
import os
os.environ['IBM_CLOUD_API_KEY'] = ''
os.environ['WATSONX_AI_ENDPOINT'] = 'https://us-south.ml.cloud.ibm.com'
os.environ['PROJECT_ID'] = '156312e8-6d77-41b3-978f-efa1aed6e1a1'

# %%
import os
from dotenv import load_dotenv
from typing import Any, List, Mapping, Optional, Union, Dict
from pydantic import BaseModel, Extra
try:
    from langchain import PromptTemplate
    from langchain.chains import LLMChain, SimpleSequentialChain
    from langchain.document_loaders import PyPDFLoader
    from langchain.indexes import VectorstoreIndexCreator #vectorize db index with chromadb
    from langchain.embeddings import HuggingFaceEmbeddings #for using HugginFace embedding models
    from langchain.text_splitter import CharacterTextSplitter #text splitter
    from langchain.llms.base import LLM
    from langchain.llms.utils import enforce_stop_tokens
except ImportError:
    raise ImportError("Could not import langchain: Please install ibm-generative-ai[langchain] extension.")

from ibm_watson_machine_learning.foundation_models import Model
from ibm_watson_machine_learning.metanames import GenTextParamsMetaNames as GenParams

# %%
#config Watsonx.ai environment
load_dotenv()
api_key = os.getenv("IBM_CLOUD_API_KEY", None)
ibm_cloud_url = os.getenv("WATSONX_AI_ENDPOINT", None)
project_id = os.getenv("PROJECT_ID", None)
if api_key is None or ibm_cloud_url is None or project_id is None:
    print("Ensure you copied the .env file that you created earlier into the same directory as this notebook")
else:
    creds = {
        "url": ibm_cloud_url,
        "apikey": api_key 
    }

# %%
##initializing WatsonX model
params = {
    GenParams.DECODING_METHOD: "sample",
    GenParams.MIN_NEW_TOKENS: 1,
    GenParams.MAX_NEW_TOKENS: 100,
    GenParams.RANDOM_SEED: 42,
    GenParams.TEMPERATURE: 0.5,
    GenParams.TOP_K: 50,
    GenParams.TOP_P:1
}

model = Model(
    model_id='google/flan-ul2',
    params=params,
    credentials=creds,
    project_id=project_id)

# %% [markdown]
# In order to use WatsonX-based LLMs with Langchain, the LLM object must be of class `BaseLanguageModel` (see [Langchain docs](https://api.python.langchain.com/en/latest/schema/langchain.schema.language_model.BaseLanguageModel.html)). We'll use the custom class below to accomplish this.

# %%
# Wrap the WatsonX Model in a langchain.llms.base.LLM subclass to allow LangChain to interact with the model

class LangChainInterface(LLM, BaseModel):
    credentials: Optional[Dict] = None
    model: Optional[str] = None
    params: Optional[Dict] = None
    project_id : Optional[str]=None

    class Config:
        """Configuration for this pydantic object."""
        extra = Extra.forbid

    @property
    def _identifying_params(self) -> Mapping[str, Any]:
        """Get the identifying parameters."""
        _params = self.params or {}
        return {
            **{"model": self.model},
            **{"params": _params},
        }
    
    @property
    def _llm_type(self) -> str:
        """Return type of llm."""
        return "IBM WATSONX"

    def _call(self, prompt: str, stop: Optional[List[str]] = None) -> str:
        """Call the WatsonX model"""
        params = self.params or {}
        model = Model(model_id=self.model, params=params, credentials=self.credentials, project_id=self.project_id)
        text = model.generate_text(prompt)
        if stop is not None:
            text = enforce_stop_tokens(text, stop)
        return text

llm_model = LangChainInterface(model='google/flan-ul2', credentials=creds, params=params, project_id=project_id)

# %%
##predict with the model
text = "Where is the capital of South Korea"
llm_model(text)
# Out:
# 'seoul'

# %% [markdown]
# ## 3. Prompt Templates & Chains
#
# In the previous example, the user input is sent directly to the LLM. However, when using an LLM in an application, you will usually need to reuse the same prompt across multiple scenarios
#
# - Accepting user input and contruct a prompt
# - Generating mutiple prompts from an collection of data points in a dataset

# %%
# Define the prompt templates
prompt = PromptTemplate(
  input_variables=["country"],
  template= "where is the capital of {country}?",
)

# Chaining 
chain = LLMChain(llm=llm_model, prompt=prompt)

# Getting predictions
countries = ["USA", "England", "Japan", "Saudi Arabia"]
for country in countries:
    response = chain.run(country)
    print(prompt.format(country=country) + " = " + response)
# Out:
# where is the capital of USA? = washington dc
# where is the capital of England? = london
# where is the capital of Japan? = tokyo
# where is the capital of Saudi Arabia? = jeddah

# %% [markdown]
# ## 4. Simple sequential chains
# The utility of LangChain becomes apparent as we chain outputs of one model as input to another model. Here's a simple example where one generates a question which the other model answers.
#
# LangChain determines a model's output based on its response.  In our examples, the first model creates a response to the end prompt of "Question:" which LangChain maps as an input variable called "question" which it passes to the 2nd model.

# %%
## Create two sequential prompts 
pt1 = PromptTemplate(input_variables=["topic"], template="Generate a random question about {topic}: Question: ")
pt2 = PromptTemplate(
    input_variables=["question"],
    template="Answer the following question: {question}",
)

# %%
flan = LangChainInterface(model='google/flan-ul2', credentials=creds, params=params, project_id=project_id)
model = LangChainInterface(model='google/flan-ul2', credentials=creds, project_id=project_id)

# %%
prompt_to_flan = LLMChain(llm=flan, prompt=pt1)
flan_to_model = LLMChain(llm=model, prompt=pt2)
qa = SimpleSequentialChain(chains=[prompt_to_flan, flan_to_model], verbose=True)

# %%
qa.run("artificial intelligence")
# Out:
# > Entering new SimpleSequentialChain chain...
# What does the term "artificial intelligence" mean?
# intelligent computer program
#
# > Finished chain.
# 'intelligent computer program'

# %% [markdown]
# ## 5. Easy Loading of Documents Using Lang Chain
# LangChain makes it easy to extract passages from documents so that you can answering questions based on your document's content.

# %%
# !wget https://github.com/hwchase17/chroma-langchain/blob/master/state_of_the_union.txt -O state_of_the_union.txt
# Out:
# --2023-11-20 07:00:33--  https://github.com/hwchase17/chroma-langchain/blob/master/state_of_the_union.txt
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47228 (46K) [text/plain]
# Saving to: ‘state_of_the_union.txt’
#
# state_of_the_union. 100%[===================>]  46.12K  --.-KB/s    in 0.06s
#
# 2023-11-20 07:00:33 (734 KB/s) - ‘state_of_the_union.txt’ saved [47228/47228]

# %%
# !ls
# Out:
# state_of_the_union.txt	what_is_generative_ai.pdf

# %%
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader

# %%
loader = TextLoader('state_of_the_union.txt')
documents = loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(documents)

# %%
embeddings = HuggingFaceEmbeddings()
vectordb = Chroma.from_documents(texts, embeddings)

# %%
###initializing watsonx flan_ul2 model
params = {
    GenParams.DECODING_METHOD: "sample",
    GenParams.MIN_NEW_TOKENS: 50,
    GenParams.MAX_NEW_TOKENS: 300,
    GenParams.TEMPERATURE: 0.2,
    GenParams.TOP_K: 100,
    GenParams.TOP_P:1
}

model = LangChainInterface(model='google/flan-ul2', credentials=creds, params=params, project_id=project_id)
model_llama = LangChainInterface(model='meta-llama/llama-2-70b-chat', credentials=creds, params=params, project_id=project_id)

# %%
qa = RetrievalQA.from_chain_type(llm=model, chain_type="stuff", retriever=vectordb.as_retriever())

# %%
query = "What did the president say about Ketanji Brown Jackson"
qa.run(query)
# Out:
# 'One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence. ","","A former top litigator in private practice. A former federal public defender. And from a family of public school educators and police officers.'

# %%
chain = RetrievalQA.from_chain_type(llm=model_llama, 
                                    chain_type="stuff", 
                                    retriever=vectordb.as_retriever(), 
                                    input_key="question")

# %%
##answering based on the documents 
chain.run("What did the president say about Ketanji Brown Jackson?")
# Out:
# " The president said that he nominated Ketanji Brown Jackson to the Supreme Court 4 days ago, and that she is one of the nation's top legal minds and will continue Justice Breyer's legacy of excellence. She is a former top litigator in private practice, a former federal public defender, and from a family of public school educators and police officers."
